# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\ritu\anaconda3\lib\site-packages (4.57.6)
# Requirement already satisfied: filelock in c:\users\ritu\anaconda3\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\ritu\anaconda3\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\ritu\anaconda3\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ritu\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ritu\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ritu\anaconda3\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\ritu\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\ritu\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ritu\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ritu\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ritu\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ritu\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\ritu\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ritu\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ritu\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ritu\anaconda3\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ritu\anaconda3\lib\site-packages (from requests->transformers) (2025.8.3)

# %%
# !pip install torch torchvision torchaudio tensorflow
# Out:
# Requirement already satisfied: torch in c:\users\ritu\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: torchvision in c:\users\ritu\anaconda3\lib\site-packages (0.25.0)
# Requirement already satisfied: torchaudio in c:\users\ritu\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: tensorflow in c:\users\ritu\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: filelock in c:\users\ritu\anaconda3\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ritu\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ritu\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ritu\anaconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\ritu\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\ritu\anaconda3\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\ritu\anaconda3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: numpy in c:\users\ritu\anaconda3\lib\site-packages (from torchvision) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\ritu\anaconda3\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (3.13.1)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ritu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ritu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ritu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ritu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ritu\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ritu\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ritu\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\ritu\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\ritu\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\ritu\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ritu\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ritu\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ritu\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ritu\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ritu\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.0)

# %%
from transformers import pipeline, set_seed, GPT2Tokenizer

# %%
import os
import nltk

# %%
file_path = "unit 1.txt"

# %%
try:
    with open(file_path, "r", encoding="utf-8") as f:
        text = f.read()
    print("File loaded successfully!")
except FileNotFoundError:
    print(f"Error: '{file_path}' not found.")
# Out:
# File loaded successfully!

# %%
print("---Data Preview---")
print(text[:500]+"...")
# Out:
# ---Data Preview---
# Generative AI and Its Applications: A Foundational Briefing
#
# Executive Summary
#
# This document provides a comprehensive overview of Generative AI, synthesizing foundational concepts, technological underpinnings, and practical applications as outlined in the course materials from PES University. Generative AI represents a transformative subset of Artificial Intelligence focused on creating novel content, a capability primarily driven by the advent of Large Language Models (LLMs). The evolution of ...

# %%
set_seed(30)

# %%
prompt = "Gen AI is the future"

# %%
# !pip install tf-keras
# Out:
# Collecting tf-keras
#   Downloading tf_keras-2.20.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\ritu\anaconda3\lib\site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.13.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.12.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\ritu\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ritu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ritu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ritu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ritu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ritu\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.8)
# Requirement already satisfied: pillow in c:\users\ritu\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (11.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ritu\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ritu\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ritu\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\ritu\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (13.9.4)
# Requirement already satisfied: namex in c:\users\ritu\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\ritu\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ritu\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ritu\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ritu\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ritu\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Downloading tf_keras-2.20.1-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------ --------- 1.3/1.7 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 8.5 MB/s eta 0:00:00
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.20.1

# %%
fast_generator = pipeline('text-generation', model='distilgpt2')
output_fast = fast_generator(prompt, max_length=25, num_return_sequences=1)
print(output_fast[0]['generated_text'])
# Out:
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=25) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gen AI is the future of artificial intelligence. In short, AI is not just a technology that is not a technology that is merely an invention and a tool for us. This is why AI is not just a technological technology that is not a technology that is merely an invention and a tool for us. AI is not just a technology that is not a technology that is merely an invention and a tool for us. It is a technology that is not a technology that is merely an invention and a tool for us. It is a technology that is not a technology that is merely an invention and a tool for us. It is a technology that is not a technology that is simply an invention and a tool for us. It is a technology that is not a technology that is simply an invention and a tool for us. It is a technology that is not a technology that is simply an invention and a tool for us. The technology that is not a technology that is simply an invention and a tool for us. It is a technology that is not a technology that is merely an invention and a tool for us. It is a technology that is not a technology that is merely an invention and a tool for us. It is a technology that is not a technology that is simply an invention and a tool for us. And

# %%
fast_generator = pipeline('text-generation', model='gpt2')
output_fast = fast_generator(prompt, max_length=25, num_return_sequences=1)
print(output_fast[0]['generated_text'])
# Out:
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=25) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Gen AI is the future of our world. This is why I am very excited about the AI revolution. If AI is to replace the traditional role of the human being, we will have to create new opportunities for the human. This is a question that needs to be answered.
#
# A revolution in AI is not going to be easy. The challenge is to find the right technology that will bring a greater level of freedom to human beings. The challenge is to make AI so powerful that it will be able to do what the human does best: gather intelligence in the best way possible.
#
# The latest research by Dr. Alain Blanquet and Dr. J. Philippe Sanger, for example, shows that intelligent machines will become smarter and more complex as they become more complex. The new research is very compelling and it shows that AI can be used more effectively in a variety of domains.
#
# The future of the human race, however, is not yet here. For now, we have to keep in mind that the future of the human race is not yet here. The future of humanity is not yet coming. What we are left with is a very different race.
#
# I'm particularly interested in the topic of social control, especially the control of power. I'm not sure that

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# %%
sample_sentence = "Python Community is revolutionary"

# %%
tokens = tokenizer.tokenize(sample_sentence)
print(f"Tokens: {tokens}")
# Out:
# Tokens: ['Python', 'ĠCommunity', 'Ġis', 'Ġrevolutionary']

# %%
token_ids = tokenizer.convert_tokens_to_ids(tokens)
print(f"Token IDs: {token_ids}")
# Out:
# Token IDs: [37906, 8108, 318, 12253]

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng', quiet=True)
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab')
pos_tags = nltk.pos_tag(nltk.word_tokenize(sample_sentence))
print(f"POS Tags: {pos_tags}")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Ritu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# POS Tags: [('Python', 'NNP'), ('Community', 'NNP'), ('is', 'VBZ'), ('revolutionary', 'JJ')]

# %%
ner_pipeline = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu

# %%
snippet = text[:500]
entities = ner_pipeline(snippet)
print(f"{'Entity':<20} | {'Type':<10} | {'Score':<5}")
print("-"*45)
for entity in entities:
    if entity['score']>0.90:
        print(f"{entity['word']:<20} | {entity['entity_group']:<10} | {entity['score']:<2f}")
# Out:
# Entity               | Type       | Score
# ---------------------------------------------
# AI                   | MISC       | 0.984341
# PES University       | ORG        | 0.992896
# AI                   | MISC       | 0.983335
# Language Models      | MISC       | 0.950317

# %%
transformer_section = """
The introduction of the Transformer architecture in the 2017 paper "Attention is all you need" was a watershed moment in AI. It provided a more effective and scalable way to handle sequential data like text, replacing older, less efficient methods like recurrence (RNNs) and convolutions.
The fundamental innovation of the Transformer is the attention mechanism. This component allows the model to weigh the importance of different words (tokens) in the input sequence when making a prediction. In essence, for each word it processes, the model can "pay attention" to all other words in the input, helping it understand context, resolve ambiguity, and handle long-range dependencies. This is crucial for tasks like translation, summarization, and question answering.
The Transformer architecture consists of an encoder stack (to process the input) and a decoder stack (to generate the output), both of which heavily utilize multi-head attention and feed-forward networks.
"""

# %%
from transformers import pipeline
fast_sum = pipeline("text2text-generation", model="sshleifer/distilbart-cnn-12-6")
res_fast = fast_sum(transformer_section, max_length=60, min_length=30, do_sample=False)
print(res_fast[0]['generated_text'])
# Out:
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# C:\Users\Ritu\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Ritu\.cache\huggingface\hub\models--sshleifer--distilbart-cnn-12-6. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu
#  The introduction of the Transformer architecture in the 2017 paper "Attention is all you need" was a watershed moment in AI . It provided a more effective and scalable way to handle sequential data like text, replacing older, less efficient methods like recurrence (RNNs) and conv

# %%
from transformers import pipeline
fast_sum = pipeline("summarization", model="sshleifer/distilbart-cnn-12-6")
res_fast = fast_sum(transformer_section, max_length=60, min_length=30, do_sample=False)
print(res_fast[0]['summary_text'])
# Out:
# Device set to use cpu
#  The introduction of the Transformer architecture in the 2017 paper "Attention is all you need" was a watershed moment in AI . It provided a more effective and scalable way to handle sequential data like text, replacing older, less efficient methods like recurrence (RNNs) and conv

# %%
smart_sum = pipeline("summarization", model="facebook/bart-large-cnn")
res_smart = smart_sum(transformer_section, max_length=60, min_length=30, do_sample=False)
print(res_smart[0]['summary_text'])
# Out:
# config.json: 0.00B [00:00, ?B/s]
# C:\Users\Ritu\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Ritu\.cache\huggingface\hub\models--facebook--bart-large-cnn. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# The introduction of the Transformer architecture in the 2017 paper "Attention is all you need" was a watershed moment in AI. It provided a more effective and scalable way to handle sequential data like text.

# %%
qa_pipeline = pipeline("question-answering", model="distilbert-base-cased-distilled-squad")
# Out:
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# C:\Users\Ritu\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Ritu\.cache\huggingface\hub\models--distilbert-base-cased-distilled-squad. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Device set to use cpu

# %%
questions = [
    "What is the fundamental innovation of the Transformer?",
    "What are the risks of using Generative AI?"
]

for q in questions:
    res = qa_pipeline(question=q, context=text[:5000])
    print(f"\nQ: {q}")
    print(f"A: {res['answer']}")
# Out:
# Q: What is the fundamental innovation of the Transformer?
# A: to identify hidden patterns, structures, and relationships within the data
#
# Q: What are the risks of using Generative AI?
# A: data privacy, intellectual property, and academic integrity

# %%
mask_filler = pipeline("fill-mask", model="bert-base-uncased")
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# C:\Users\Ritu\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Ritu\.cache\huggingface\hub\models--bert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Device set to use cpu

# %%
masked_sentence = "The goal of Generative AI is to create new [MASK]."
preds = mask_filler(masked_sentence)

for p in preds:
    print(f"{p['token_str']}: {p['score']:.2f}")
# Out:
# applications: 0.06
# ideas: 0.05
# problems: 0.05
# systems: 0.04
# information: 0.03

# %% [markdown]
# ## Assignment 2 Project

# %%
from transformers import pipeline

summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

def simplify_legal_text(text):
    prompt = f"Summarize this legal text in simple English:\n{text}"
    summary = summarizer(prompt, max_length=100, min_length=30, do_sample=False)
    return summary[0]['summary_text']

print("Paste the legal paragraph (type END on a new line to finish):")
lines = []

while True:
    line = input()
    if line.strip().upper() == "END":
        break
    lines.append(line)

legal_text = " ".join(lines)
simple_summary = simplify_legal_text(legal_text)

print("\n--- Simplified Version ---\n")
print(simple_summary)
# Out:
# Device set to use cpu
# Paste the legal paragraph (type END on a new line to finish):
#  1. Acceptance of Terms  By accessing and using App Name ("the Service"), you agree to be bound by these Terms and Conditions. If you do not agree to all of these terms, do not use the Service.  2. Use of the Service  You agree to use the Service only for lawful purposes. You are prohibited from:    Attempting to interfere with the proper working of the Service.  Uploading malicious code, viruses, or spam.  Using the Service for any unauthorized commercial purposes.  3. Intellectual Property  All content, features, and functionality (including but not limited to text, software, and logos) are the exclusive property of Company and are protected by international copyright and trademark laws.  4. Limitation of Liability  The Service is provided on an "AS IS" and "AS AVAILABLE" basis. App Name shall not be liable for any direct, indirect, or incidental damages resulting from your use of, or inability to use, the Service.  5. Privacy Policy  Your use of the Service is also governed by our Privacy Policy. Please review it to understand how we collect and use your data.  6. Termination  We reserve the right to terminate or suspend access to our Service immediately, without prior notice, for any reason whatsoever, including breach of these Terms.  7. Changes to Terms  We reserve the right to modify these terms at any time. Your continued use of the Service after changes are posted constitutes your acceptance of the new terms.  8. Governing Law  These terms shall be governed by and defined in accordance with the laws of Country/State.
#  END
# --- Simplified Version ---
#
# By accessing and using App Name ("the Service"), you agree to be bound by these Terms and Conditions. If you do not agree to all of these terms, do not use the Service. All content, features, and functionality are the exclusive property of Company and protected by international copyright and trademark laws.
